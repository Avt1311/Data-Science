# %% [markdown]
# # Theory Questions
#
# 1. What is hypothesis testing in statistics?
#  - Hypothesis testing is a statistical method used to determine whether there is enough evidence to reject a given hypothesis about a population parameter. It involves formulating a null hypothesis (
# 𝐻
# 0
#  ) and an alternative hypothesis (
# 𝐻
# 1
#  ), then using sample data to decide whether to reject
# 𝐻
# 0
#   at a chosen significance level.
#
# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
#  - Null Hypothesis (
# 𝐻
# 0
#  ): Assumes that there is no effect or no difference in the population. It represents the default or status quo.
#  - Alternative Hypothesis (
# 𝐻
# 1
#  ): Represents a claim that contradicts
# 𝐻
# 0
#  , indicating that there is an effect or a difference.
#   - Example:
# 𝐻
# 0
#  : The mean weight of apples is 150g.
#
#    - 𝐻
# 1
#  : The mean weight of apples is different from 150g.
#
#
# 3. What is the significance level in hypothesis testing, and why is it important?
#  - The significance level (
# 𝛼
# α) is the probability of rejecting the null hypothesis when it is actually true. It is chosen before the test (common values: 0.05 or 0.01) and determines the threshold for statistical significance.
#
# - Importance:
#    - Controls the risk of making a Type I error (false positive).
#    - Helps in making objective decisions in hypothesis testing.
#
# 4. What does a P-value represent in hypothesis testing?
#  - The P-value is the probability of obtaining a test statistic at least as extreme as the observed value, assuming the null hypothesis is true.
#   - **Small P-value** (
# 𝛼
# <α) → Reject
# 𝐻
# 0
#   (significant evidence against
# 𝐻
# 0
#  )
#  - **Large P-value** (
# 𝛼>α) → Fail to reject
# 𝐻
# 0
#   (not enough evidence against
# 𝐻
# 0
#  )
#
# 5. How do you interpret the P-value in hypothesis testing?
#  - If P≤α: There is sufficient evidence to reject the null hypothesis.
#  - If P>α: There is not enough evidence to reject the null hypothesis.
#  - Example: If 𝑃 = 0.03 and 𝛼 = 0.05, we reject
# 𝐻
# 0
#   because there is strong evidence against it.
#
# 6. What are Type 1 and Type 2 errors in hypothesis testing?
#  - Type 1 Error: Rejecting a true null hypothesis (
# 𝐻
# 0). It is controlled by the significance level (α).
#  - Type 2 Error: Failing to reject a false null hypothesis. It depends on the sample size and effect size.
#  - Example:
#     - Type 1 Error: Convicting an innocent person.
#     - Type 2 Error: Letting a guilty person go free.
#
# 7. What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
#  - One-tailed test: Tests for an effect in only one direction (e.g., greater than or less than).
#  - Two-tailed test: Tests for an effect in both directions (e.g., different from).
#  - Example:
#
#    - One-tailed: 𝐻1: 𝜇>100
#    - Two-tailed: 𝐻1: 𝜇≠100
#
# 8. What is the Z-test, and when is it used in hypothesis testing?
#  - A Z-test is used to determine if there is a significant difference between a sample mean and a population mean when the population variance is known and the sample size is large (n>30)
#
# 9.  How do you calculate the Z-score, and what does it represent in hypothesis testing?
#  -        Z=  xˉ− μ / σ/✓n
#
#  where :
#    - x = sample mean
#    - μ = population mean
#    - σ = population standard deviation
#    - n = sample size
#
#    The Z-score tells us how many standard deviations the sample mean is from the population mean.
#
# 10. What is the T-distribution, and when should it be used instead of the normal distribution?
#  - The T-distribution is similar to the normal distribution but has heavier tails. It is used instead of the normal distribution when the sample size is small (n<30) and the population standard deviation is unknown.
#
# 11. What is the difference between a Z-test and a T-test?
#  - Z-test: Used when population variance is known and n>30.
#  - T-test: Used when population variance is unknown and n<30.
#
# 12. What is the T-test, and how is it used in hypothesis testing
#  - A T-test is used to compare the means of two groups to determine if they are significantly different. It is applied when the population standard deviation is unknown.
#  - Types:
#      - One-sample T-test: Compares sample mean with population mean.
#      - Independent T-test: Compares means of two independent groups.
#      - Paired T-test: Compares means of the same group before and after treatment.
#
# 13. What is the relationship between Z-test and T-test in hypothesis testing?
#  - Both tests compare means, but:
#       - Z-test is used when the sample size is large and variance is known.
#       - T-test is used when the sample size is small and variance is unknown.
#       - As n increases, the T-distribution approaches the normal distribution, making the T-test similar to the Z-test.
# 14. What is a confidence interval, and how is it used to interpret statistical results?
#  - A confidence interval (CI) is a range of values that estimates the true population parameter. It is calculated as:
#
#      𝐶𝐼 = 𝑥ˉ± 𝑍  X 𝜎/✓𝑛
#        - A 95% confidence interval means we are 95% confident the true mean lies within this range.
# 15. What is the margin of error, and how does it affect the confidence interval?
#  - The margin of error (MOE) represents the maximum expected difference between the sample statistic and the population parameter.
#  - A larger MOE leads to a wider CI, reducing precision.
#  - A smaller MOE gives a narrower CI, increasing precision.
#
# 16. How is Bayes' Theorem used in statistics, and what is its significance?
#  - Bayes' Theorem calculates conditional probabilities. It is used in:
#       - Machine learning
#       - Medical diagnosis
#       - Spam detection
# 17. What is the Chi-square distribution, and when is it used?
#  - The Chi-square distribution is used in tests of variance and categorical data analysis (e.g., independence tests).
#
# 18. What is the Chi-square goodness of fit test, and how is it applied?
#  - It tests whether observed frequencies match expected frequencies.
#  -   χ
# 2 =∑  (O−E) 2 / E
#   - where O = observed, E = expected.
#
# 19. What is the F-distribution, and when is it used in hypothesis testing?
#  - The F-distribution is used in tests comparing variance (e.g., ANOVA, F-test).
#
# 20. What is an ANOVA test, and what are its assumptions?
#  - ANOVA (Analysis of Variance) tests whether three or more means are different.
#  - Assumptions:
#      - Normality
#      - Independence
#      - Equal variance
#
# 21. What are the different types of ANOVA tests?
#  - One-way ANOVA (one independent variable)
#  -  Two-way ANOVA (two independent variables)
#  - Repeated measures ANOVA (same subjects, multiple conditions)
#
# 22. What is the F-test, and how does it relate to hypothesis testing?
#  - The F-test compares variances of two groups. It is used in ANOVA and regression analysis.

# %% [markdown]
# # Practical Questions

# %%
# 1 Write a Python program to perform a Z-test for comparing a sample mean to a known population mean and interpret the results?


import scipy.stats as stats
import numpy as np

def margin_of_error(confidence_level, sample_std, sample_size):
    z_score = stats.norm.ppf(1 - (1 - confidence_level) / 2)
    return z_score * (sample_std / np.sqrt(sample_size))

# Example usage:
confidence_level = 0.95
sample_std = 12
sample_size = 100
moe = margin_of_error(confidence_level, sample_std, sample_size)
print(f"Margin of Error: {moe:.4f}")
# Out:
# Margin of Error: 2.3520

# %%
# 2 Simulate random data to perform hypothesis testing and calculate the corresponding P-value using Python?


import numpy as np
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=100)
group2 = np.random.normal(loc=55, scale=10, size=100)
from scipy import stats

# Perform a t-test
t_statistic, p_value = stats.ttest_ind(group1, group2)

# Display the results
print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")
# Out:
# T-statistic: -4.7546959435052765
# P-value: 3.8191352626795345e-06

# %%
# 3. Implement a one-sample Z-test using Python to compare the sample mean with the population mean?


import numpy as np
import scipy.stats as stats

np.random.seed(42)

sample_size = 50
sample_data = np.random.normal(loc=52, scale=5, size=sample_size)

# Define population parameters
population_mean = 50  # Known population mean
population_std = 5    # Known population standard deviation

# Calculate sample mean
sample_mean = np.mean(sample_data)

# Calculate the Z-statistic
z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Calculate the P-value (two-tailed)
p_value = 2 * (1 - stats.norm.cdf(np.abs(z_statistic)))

# Display the results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_statistic:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Sample Mean: 50.87
# Z-statistic: 1.23
# P-value: 0.2172

# %%
# 4 Perform a two-tailed Z-test using Python and visualize the decision region on a plot?


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
np.random.seed(42)

sample_size = 50
sample_data = np.random.normal(loc=52, scale=5, size=sample_size)

# Define population parameters
population_mean = 50
population_std = 5

# Calculate sample mean
sample_mean = np.mean(sample_data)

# Calculate the Z-statistic
z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

# Calculate the P-value (two-tailed)
p_value = 2 * (1 - stats.norm.cdf(np.abs(z_statistic)))

# Display the results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"Z-statistic: {z_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

# Visualization
# Define the critical Z-values for a two-tailed test at alpha = 0.05
alpha = 0.05
critical_value = stats.norm.ppf(1 - alpha / 2)

# Create a range of Z values
z_values = np.linspace(-4, 4, 1000)
z_distribution = stats.norm.pdf(z_values)

# Plot the Z-distribution
plt.figure(figsize=(10, 6))
plt.plot(z_values, z_distribution, label='Standard Normal Distribution', color='blue')

# Fill the critical regions
plt.fill_between(z_values, z_distribution, where=(z_values <= -critical_value) | (z_values >= critical_value),
                 color='red', alpha=0.5, label='Rejection Region')

# Mark the Z-statistic on the plot
plt.axvline(z_statistic, color='green', linestyle='--', label=f'Z-statistic: {z_statistic:.2f}')

# Add labels and title
plt.title('Two-Tailed Z-Test Decision Region')
plt.xlabel('Z-value')
plt.ylabel('Probability Density')
plt.legend()
plt.grid()
plt.show()
# Out:
# Sample Mean: 50.87
# Z-statistic: 1.23
# P-value: 0.2172

# %%
# 5 Create a Python function that calculates and visualizes Type 1 and Type 2 errors during hypothesis testing


import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

def visualize_errors(population_mean, sample_mean, population_std, sample_size, alpha):
    # Calculate the Z-statistic
    z_statistic = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    # Critical Z-value for the given alpha (two-tailed)
    critical_value = stats.norm.ppf(1 - alpha / 2)

    # Calculate Type I Error (α)
    type_1_error = alpha

    # Calculate Type II Error (β)
    # Assume the true mean is different from the population mean
    true_mean = population_mean + 5  # Example: true mean is 5 units greater
    z_beta = (critical_value * (population_std / np.sqrt(sample_size)) + true_mean - population_mean) / (population_std / np.sqrt(sample_size))
    type_2_error = stats.norm.cdf(z_beta) - stats.norm.cdf(-critical_value)

    # Display the results
    print(f"Z-statistic: {z_statistic:.2f}")
    print(f"Type I Error (α): {type_1_error:.4f}")
    print(f"Type II Error (β): {type_2_error:.4f}")

    # Visualization
    z_values = np.linspace(-4, 4, 1000)
    z_distribution = stats.norm.pdf(z_values)

    plt.figure(figsize=(10, 6))
    plt.plot(z_values, z_distribution, label='Standard Normal Distribution', color='blue')

    # Fill the critical regions for Type I Error
    plt.fill_between(z_values, z_distribution, where=(z_values <= -critical_value) | (z_values >= critical_value),
                     color='red', alpha=0.5, label='Type I Error Region (α)')

    # Fill the Type II Error region
    plt.fill_between(z_values, z_distribution, where=(z_values > -critical_value) & (z_values < z_beta),
                     color='orange', alpha=0.5, label='Type II Error Region (β)')

    # Mark the Z-statistic on the plot
    plt.axvline(z_statistic, color='green', linestyle='--', label=f'Z-statistic: {z_statistic:.2f}')

    # Add labels and title
    plt.title('Type I and Type II Errors in Hypothesis Testing')
    plt.xlabel('Z-value')
    plt.ylabel('Probability Density')
    plt.legend()
    plt.grid()
    plt.show()

# Example usage
visualize_errors(population_mean=50, sample_mean=52, population_std=5, sample_size=50, alpha=0.05)
# Out:
# Z-statistic: 2.83
# Type I Error (α): 0.0500
# Type II Error (β): 0.9750

# %%
# 6 Write a Python program to perform an independent T-test and interpret the results?


import numpy as np
from scipy import stats

# Step 1: Simulate two independent samples
np.random.seed(42)  # For reproducibility
group1 = np.random.normal(loc=50, scale=10, size=100)
group2 = np.random.normal(loc=55, scale=10, size=100)

# Step 2: Perform the independent T-test
t_statistic, p_value = stats.ttest_ind(group1, group2)

# Step 3: Interpret the results
alpha = 0.05  # Significance level

print(f"T-statistic: {t_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two groups.")
# Out:
# T-statistic: -4.75
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between the two groups.

# %%
# 7 Perform a paired sample T-test using Python and visualize the comparison results?


import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate related samples
np.random.seed(42)  # For reproducibility
n = 30  # Number of samples
before_treatment = np.random.normal(loc=50, scale=5, size=n)  # Before treatment
after_treatment = before_treatment + np.random.normal(loc=3, scale=2, size=n)  # After treatment (mean increase of 3)

# Step 2: Perform the paired sample T-test
t_statistic, p_value = stats.ttest_rel(before_treatment, after_treatment)

# Step 3: Interpret the results
alpha = 0.05  # Significance level
print(f"T-statistic: {t_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two groups.")

# Step 4: Visualize the results
plt.figure(figsize=(10, 6))
plt.plot(before_treatment, label='Before Treatment', marker='o', linestyle='-', color='blue')
plt.plot(after_treatment, label='After Treatment', marker='o', linestyle='-', color='orange')
plt.title('Comparison of Before and After Treatment')
plt.xlabel('Sample Index')
plt.ylabel('Measurement')
plt.axhline(y=np.mean(before_treatment), color='blue', linestyle='--', label='Mean Before Treatment')
plt.axhline(y=np.mean(after_treatment), color='orange', linestyle='--', label='Mean After Treatment')
plt.legend()
plt.grid()
plt.show()
# Out:
# T-statistic: -8.11
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between the two groups.

# %%
# 8 Simulate data and perform both Z-test and T-test, then compare the results using Python?



import numpy as np
import scipy.stats as stats

# Step 1: Simulate data
np.random.seed(42)  # For reproducibility
sample_size = 30
population_mean = 50
population_std = 10

# Generate two independent samples
group1 = np.random.normal(loc=population_mean, scale=population_std, size=sample_size)
group2 = np.random.normal(loc=population_mean + 5, scale=population_std, size=sample_size)  # Group 2 has a mean 5 units higher

# Step 2: Perform Z-test
z_statistic = (np.mean(group1) - np.mean(group2)) / (population_std / np.sqrt(sample_size))
p_value_z = 2 * (1 - stats.norm.cdf(np.abs(z_statistic)))  # Two-tailed p-value

# Step 3: Perform T-test
t_statistic, p_value_t = stats.ttest_ind(group1, group2)

# Step 4: Compare Results
alpha = 0.05  # Significance level

print("Z-test Results:")
print(f"Z-statistic: {z_statistic:.2f}")
print(f"P-value: {p_value_z:.4f}")
if p_value_z < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups (Z-test).")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two groups (Z-test).")

print("\nT-test Results:")
print(f"T-statistic: {t_statistic:.2f}")
print(f"P-value: {p_value_t:.4f}")
if p_value_t < alpha:
    print("Reject the null hypothesis: There is a significant difference between the two groups (T-test).")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the two groups (T-test).")
# Out:
# Z-test Results:
# Z-statistic: -3.11
# P-value: 0.0019
# Reject the null hypothesis: There is a significant difference between the two groups (Z-test).
#
# T-test Results:
# T-statistic: -2.40
# P-value: 0.0197
# Reject the null hypothesis: There is a significant difference between the two groups (T-test).

# %%
# 9 Write a Python function to calculate the confidence interval for a sample mean and explain its significance

import numpy as np
import scipy.stats as stats

def confidence_interval(data, confidence=0.95):
    """
    Calculate the confidence interval for a sample mean.

    Parameters:
    data (array-like): Sample data.
    confidence (float): Confidence level (default is 0.95 for 95% confidence).

    Returns:
    tuple: Lower and upper bounds of the confidence interval.
    """
    # Calculate the sample mean and standard error
    sample_mean = np.mean(data)
    sample_std = np.std(data, ddof=1)  # Sample standard deviation
    n = len(data)  # Sample size
    standard_error = sample_std / np.sqrt(n)

    # Calculate the critical value for the specified confidence level
    critical_value = stats.t.ppf((1 + confidence) / 2, df=n-1)

    # Calculate the margin of error
    margin_of_error = critical_value * standard_error

    # Calculate the confidence interval
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    return lower_bound, upper_bound

# Example usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=10, size=30)  # Simulated sample data
ci = confidence_interval(sample_data, confidence=0.95)
print(f"95% Confidence Interval for the sample mean: {ci}")
# Out:
# 95% Confidence Interval for the sample mean: (44.75785181035169, 51.47921027262756)

# %%
# 10 Write a Python program to calculate the margin of error for a given confidence level using sample data?


import numpy as np
import scipy.stats as stats

def margin_of_error(data, confidence=0.95):
    """
    Calculate the margin of error for a given confidence level.

    Parameters:
    data (array-like): Sample data.
    confidence (float): Confidence level (default is 0.95 for 95% confidence).

    Returns:
    float: Margin of error.
    """
    # Calculate the sample standard deviation
    sample_std = np.std(data, ddof=1)  # Sample standard deviation
    n = len(data)  # Sample size

    # Calculate the critical value for the specified confidence level
    z_critical = stats.norm.ppf((1 + confidence) / 2)

    # Calculate the margin of error
    margin_of_error = z_critical * (sample_std / np.sqrt(n))

    return margin_of_error

# Example usage
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=10, size=30)  # Simulated sample data
moe = margin_of_error(sample_data, confidence=0.95)
print(f"Margin of Error for 95% confidence level: {moe:.2f}")
# Out:
# Margin of Error for 95% confidence level: 3.22

# %%
# 11 Implement a Bayesian inference method using Bayes' Theorem in Python and explain the process?



import numpy as np

def bayesian_inference(prior, likelihood, evidence):

    posterior = (likelihood * prior) / evidence
    return posterior


prior_disease = 0.01

likelihood_positive_given_disease = 0.9

likelihood_positive_given_no_disease = 0.05

# Marginal likelihood: Total probability of testing positive (P(E))
# P(E) = P(E | H) * P(H) + P(E | ~H) * P(~H)
p_no_disease = 1 - prior_disease  # Probability of not having the disease
marginal_likelihood = (likelihood_positive_given_disease * prior_disease) + \
                      (likelihood_positive_given_no_disease * p_no_disease)

# Calculate the posterior probability (P(H | E))
posterior_probability = bayesian_inference(prior_disease, likelihood_positive_given_disease, marginal_likelihood)

print(f"Posterior Probability of having the disease given a positive test result: {posterior_probability:.4f}")
# Out:
# Posterior Probability of having the disease given a positive test result: 0.1538

# %%
# 12  Perform a Chi-square test for independence between two categorical variables in Python


import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# Step 1: Prepare the data
# Create a contingency table
data = {
    'Variable A': ['Yes', 'Yes', 'No', 'No'],
    'Variable B': ['Group 1', 'Group 2', 'Group 1', 'Group 2'],
    'Count': [30, 10, 20, 40]
}

# Convert to a DataFrame
df = pd.DataFrame(data)

# Create a contingency table
contingency_table = df.pivot(index='Variable A', columns='Variable B', values='Count')
print("Contingency Table:")
print(contingency_table)

# Step 2: Perform the Chi-square test
chi2_statistic, p_value, dof, expected = chi2_contingency(contingency_table)

# Step 3: Interpret the results
alpha = 0.05  # Significance level
print(f"\nChi-square Statistic: {chi2_statistic:.2f}")
print(f"P-value: {p_value:.4f}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant association between the two variables.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between the two variables.")
# Out:
# Contingency Table:
# Variable B  Group 1  Group 2
# Variable A
# No               20       40
# Yes              30       10
#
# Chi-square Statistic: 15.04
# P-value: 0.0001
# Degrees of Freedom: 1
# Expected Frequencies:
# [[30. 30.]
#  [20. 20.]]
# Reject the null hypothesis: There is a significant association between the two variables.

# %%
# 13 Write a Python program to calculate the expected frequencies for a Chi-square test based on observed data?



import numpy as np
import pandas as pd

def calculate_expected_frequencies(observed):

    if not isinstance(observed, pd.DataFrame):
        observed = pd.DataFrame(observed)

    # Calculate the row totals and column totals
    row_totals = observed.sum(axis=1).values.reshape(-1, 1)  # Reshape for broadcasting
    column_totals = observed.sum(axis=0).values  # Column totals

    # Total number of observations
    total = observed.values.sum()

    # Calculate expected frequencies
    expected = (row_totals * column_totals) / total
    return expected

# Example observed data (contingency table)
observed_data = np.array([[30, 10],
                           [20, 40]])

# Calculate expected frequencies
expected_frequencies = calculate_expected_frequencies(observed_data)

# Display the results
print("Observed Frequencies:")
print(observed_data)
print("\nExpected Frequencies:")
print(expected_frequencies)
# Out:
# Observed Frequencies:
# [[30 10]
#  [20 40]]
#
# Expected Frequencies:
# [[20. 20.]
#  [30. 30.]]

# %%
 # 14 Perform a goodness-of-fit test using Python to compare the observed data to an expected distribution



 import numpy as np
from scipy.stats import chisquare

# Step 1: Prepare the observed data
observed_data = np.array([50, 30, 20])  # Example observed frequencies

# Step 2: Define the expected distribution
# For example, we expect the proportions to be 50%, 30%, and 20%
total_count = observed_data.sum()
expected_proportions = np.array([0.5, 0.3, 0.2])  # Expected proportions
expected_data = expected_proportions * total_count  # Calculate expected frequencies

# Step 3: Perform the Chi-square goodness-of-fit test
chi2_statistic, p_value = chisquare(observed_data, f_exp=expected_data)

# Step 4: Interpret the results
alpha = 0.05  # Significance level
print(f"Chi-square Statistic: {chi2_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")
# Out:
# Chi-square Statistic: 0.00
# P-value: 1.0000
# Fail to reject the null hypothesis: The observed data fits the expected distribution.

# %%
 # 15  Create a Python script to simulate and visualize the Chi-square distribution and discuss its characteristics


 import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Set the degrees of freedom
degrees_of_freedom = [1, 2, 5, 10, 20]

# Create a range of x values
x = np.linspace(0, 50, 1000)

# Plot the Chi-square distribution for different degrees of freedom
plt.figure(figsize=(10, 6))

for df in degrees_of_freedom:
    # Calculate the Chi-square probability density function (PDF)
    pdf = chi2.pdf(x, df)
    plt.plot(x, pdf, label=f'df = {df}')

# Add labels and title
plt.title('Chi-square Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density Function (PDF)')
plt.legend()
plt.grid()
plt.xlim(0, 50)
plt.ylim(0, 0.25)
plt.show()

# %%
 # 16 Implement an F-test using Python to compare the variances of two random samples



 import numpy as np
from scipy import stats

# Step 1: Simulate two independent samples
np.random.seed(42)  # For reproducibility
sample_size = 30
# Sample 1: Normal distribution with mean=50, std=10
sample1 = np.random.normal(loc=50, scale=10, size=sample_size)
# Sample 2: Normal distribution with mean=55, std=15
sample2 = np.random.normal(loc=55, scale=15, size=sample_size)

# Step 2: Calculate the variances
var1 = np.var(sample1, ddof=1)  # Sample variance for sample1
var2 = np.var(sample2, ddof=1)  # Sample variance for sample2

# Step 3: Perform the F-test
f_statistic = var1 / var2  # F-statistic
df1 = sample_size - 1  # Degrees of freedom for sample1
df2 = sample_size - 1  # Degrees of freedom for sample2

# Calculate the p-value
p_value = 1 - stats.f.cdf(f_statistic, df1, df2)

# Step 4: Interpret the results
alpha = 0.05  # Significance level
print(f"Sample 1 Variance: {var1:.2f}")
print(f"Sample 2 Variance: {var2:.2f}")
print(f"F-statistic: {f_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: The variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: The variances are not significantly different.")
# Out:
# Sample 1 Variance: 81.00
# Sample 2 Variance: 195.06
# F-statistic: 0.42
# P-value: 0.9896
# Fail to reject the null hypothesis: The variances are not significantly different.

# %%
# 17 D Write a Python program to perform an ANOVA test to compare means between multiple groups and interpret the results


import numpy as np
from scipy import stats

# Step 1: Simulate data for multiple groups
np.random.seed(42)  # For reproducibility
group1 = np.random.normal(loc=50, scale=5, size=30)  # Group 1: mean=50, std=5
group2 = np.random.normal(loc=55, scale=5, size=30)  # Group 2: mean=55, std=5
group3 = np.random.normal(loc=60, scale=5, size=30)  # Group 3: mean=60, std=5

# Step 2: Perform the ANOVA test
f_statistic, p_value = stats.f_oneway(group1, group2, group3)

# Step 3: Interpret the results
alpha = 0.05  # Significance level
print(f"F-statistic: {f_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between group means.")
# Out:
# F-statistic: 40.98
# P-value: 0.0000
# Reject the null hypothesis: At least one group mean is significantly different.

# %%
 # 18 Perform a one-way ANOVA test using Python to compare the means of different groups and plot the results

 import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate data for multiple groups
np.random.seed(42)  # For reproducibility
group1 = np.random.normal(loc=50, scale=5, size=30)  # Group 1: mean=50, std=5
group2 = np.random.normal(loc=55, scale=5, size=30)  # Group 2: mean=55, std=5
group3 = np.random.normal(loc=60, scale=5, size=30)  # Group 3: mean=60, std=5

# Combine the data into a DataFrame for easier plotting
data = pd.DataFrame({
    'Group 1': group1,
    'Group 2': group2,
    'Group 3': group3
})

# Step 2: Perform the ANOVA test
f_statistic, p_value = stats.f_oneway(data['Group 1'], data['Group 2'], data['Group 3'])

# Step 3: Interpret the results
alpha = 0.05  # Significance level
print(f"F-statistic: {f_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between group means.")

# Step 4: Visualize the results
plt.figure(figsize=(10, 6))
plt.boxplot([data['Group 1'], data['Group 2'], data['Group 3']], labels=['Group 1', 'Group 2', 'Group 3'])
plt.title('Box Plot of Different Groups')
plt.ylabel('Values')
plt.xlabel('Groups')
plt.grid()
plt.axhline(y=np.mean(group1), color='blue', linestyle='--', label='Mean Group 1')
plt.axhline(y=np.mean(group2), color='orange', linestyle='--', label='Mean Group 2')
plt.axhline(y=np.mean(group3), color='green', linestyle='--', label='Mean Group 3')
plt.legend()
plt.show()
# Out:
# F-statistic: 40.98
# P-value: 0.0000
# Reject the null hypothesis: At least one group mean is significantly different.
# <ipython-input-19-bf02a4a419d7>:36: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data['Group 1'], data['Group 2'], data['Group 3']], labels=['Group 1', 'Group 2', 'Group 3'])

# %%
# 19 Write a Python function to check the assumptions (normality, independence, and equal variance) for ANOVA


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

def check_anova_assumptions(data):

    # Check normality using Shapiro-Wilk test
    print("Normality Test Results:")
    for column in data.columns:
        stat, p_value = stats.shapiro(data[column])
        print(f"{column}: W-statistic = {stat:.4f}, p-value = {p_value:.4f}")
        if p_value < 0.05:
            print(f"  -> {column} is not normally distributed (reject H0)\n")
        else:
            print(f"  -> {column} is normally distributed (fail to reject H0)\n")

    # Check equal variance using Levene's test
    print("Equal Variance Test Results:")
    stat, p_value = stats.levene(*[data[column] for column in data.columns])
    print(f"Levene's test: W-statistic = {stat:.4f}, p-value = {p_value:.4f}")
    if p_value < 0.05:
        print("  -> Variances are not equal (reject H0)\n")
    else:
        print("  -> Variances are equal (fail to reject H0)\n")

    # Visualize the data distribution
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=data)
    plt.title('Boxplot of Groups')
    plt.ylabel('Values')
    plt.xlabel('Groups')
    plt.grid()
    plt.show()

# Example usage
np.random.seed(42)  # For reproducibility
group1 = np.random.normal(loc=50, scale=5, size=30)
group2 = np.random.normal(loc=55, scale=5, size=30)
group3 = np.random.normal(loc=60, scale=5, size=30)

# Combine the data into a DataFrame
data = pd.DataFrame({
    'Group 1': group1,
    'Group 2': group2,
    'Group 3': group3
})

# Check ANOVA assumptions
check_anova_assumptions(data)
# Out:
# Normality Test Results:
# Group 1: W-statistic = 0.9751, p-value = 0.6868
#   -> Group 1 is normally distributed (fail to reject H0)
#
# Group 2: W-statistic = 0.9837, p-value = 0.9130
#   -> Group 2 is normally distributed (fail to reject H0)
#
# Group 3: W-statistic = 0.9628, p-value = 0.3654
#   -> Group 3 is normally distributed (fail to reject H0)
#
# Equal Variance Test Results:
# Levene's test: W-statistic = 0.1480, p-value = 0.8627
#   -> Variances are equal (fail to reject H0)

# %%
# 20 Perform a two-way ANOVA test using Python to study the interaction between two factors and visualize the results

import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Simulate data for two factors
np.random.seed(42)  # For reproducibility
factor1 = ['A', 'B']  # Factor 1 with two levels
factor2 = ['X', 'Y', 'Z']  # Factor 2 with three levels

# Create a DataFrame to hold the data
data = []
for f1 in factor1:
    for f2 in factor2:
        # Simulate data: mean varies by factor levels
        mean = 10 + (ord(f1) - ord('A')) * 5 + (ord(f2) - ord('X')) * 3
        group_data = np.random.normal(loc=mean, scale=2, size=30)
        data.extend(zip([f1]*30, [f2]*30, group_data))

df = pd.DataFrame(data, columns=['Factor1', 'Factor2', 'Response'])

# Step 2: Perform the Two-Way ANOVA test
model = ols('Response ~ C(Factor1) * C(Factor2)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# Print the ANOVA table
print(anova_table)

# Step 3: Visualize the results
# Interaction plot
plt.figure(figsize=(10, 6))
sns.pointplot(x='Factor1', y='Response', hue='Factor2', data=df,
               palette='deep', markers=['o', 's', 'D'], dodge=True)
plt.title('Interaction Plot for Two-Way ANOVA')
plt.ylabel('Response')
plt.xlabel('Factor 1')
plt.grid()
plt.show()
# Out:
#                             sum_sq     df           F        PR(>F)
# C(Factor1)             1267.232469    1.0  349.847919  1.676547e-43
# C(Factor2)             1270.184815    2.0  175.331490  1.986954e-42
# C(Factor1):C(Factor2)     1.742730    2.0    0.240560  7.864487e-01
# Residual                630.269434  174.0         NaN           NaN

# %%
# 21 Write a Python program to visualize the F-distribution and discuss its use in hypothesis testing?

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f

# Set the degrees of freedom for the numerator and denominator
df1_values = [1, 5, 10]  # Degrees of freedom for the numerator
df2_values = [1, 5, 10]   # Degrees of freedom for the denominator

# Create a range of x values
x = np.linspace(0, 5, 1000)

# Plot the F-distribution for different degrees of freedom
plt.figure(figsize=(10, 6))

for df1 in df1_values:
    for df2 in df2_values:
        # Calculate the F-distribution PDF
        pdf = f.pdf(x, df1, df2)
        plt.plot(x, pdf, label=f'df1={df1}, df2={df2}')

# Add labels and title
plt.title('F-distribution')
plt.xlabel('x')
plt.ylabel('Probability Density Function (PDF)')
plt.legend()
plt.grid()
plt.xlim(0, 5)
plt.ylim(0, 1)
plt.show()

# %%
# 22 Perform a one-way ANOVA test in Python and visualize the results with boxplots to compare group means



import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# Step 1: Simulate data for multiple groups
np.random.seed(42)  # For reproducibility
group1 = np.random.normal(loc=50, scale=5, size=30)  # Group 1: mean=50, std=5
group2 = np.random.normal(loc=55, scale=5, size=30)  # Group 2: mean=55, std=5
group3 = np.random.normal(loc=60, scale=5, size=30)  # Group 3: mean=60, std=5

# Combine the data into a DataFrame for easier plotting
data = pd.DataFrame({
    'Group 1': group1,
    'Group 2': group2,
    'Group 3': group3
})

# Step 2: Perform the One-Way ANOVA test
f_statistic, p_value = stats.f_oneway(data['Group 1'], data['Group 2'], data['Group 3'])

# Step 3: Interpret the results
alpha = 0.05  # Significance level
print(f"F-statistic: {f_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: At least one group mean is significantly different.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between group means.")

# Step 4: Visualize the results
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title('Box Plot of Different Groups')
plt.ylabel('Values')
plt.xlabel('Groups')
plt.grid()
plt.axhline(y=np.mean(group1), color='blue', linestyle='--', label='Mean Group 1')
plt.axhline(y=np.mean(group2), color='orange', linestyle='--', label='Mean Group 2')
plt.axhline(y=np.mean(group3), color='green', linestyle='--', label='Mean Group 3')
plt.legend()
plt.show()
# Out:
# F-statistic: 40.98
# P-value: 0.0000
# Reject the null hypothesis: At least one group mean is significantly different.

# %%
# 23 Simulate random data from a normal distribution, then perform hypothesis testing to evaluate the means


import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Simulate random data from a normal distribution
np.random.seed(42)  # For reproducibility
group1 = np.random.normal(loc=50, scale=5, size=30)  # Group 1: mean=50, std=5
group2 = np.random.normal(loc=55, scale=5, size=30)  # Group 2: mean=55, std=5

# Combine the data into a DataFrame for easier plotting
data = pd.DataFrame({
    'Group 1': group1,
    'Group 2': group2
})

# Step 2: Formulate Hypotheses
# Null Hypothesis (H0): The means of the two groups are equal (μ1 = μ2)
# Alternative Hypothesis (H1): The means of the two groups are not equal (μ1 ≠ μ2)

# Step 3: Perform the T-test
t_statistic, p_value = stats.ttest_ind(data['Group 1'], data['Group 2'])

# Step 4: Interpret the results
alpha = 0.05  # Significance level
print(f"T-statistic: {t_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the means.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the means.")

# Step 5: Visualize the results
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title('Box Plot of Group Means')
plt.ylabel('Values')
plt.xlabel('Groups')
plt.grid()
plt.axhline(y=np.mean(group1), color='blue', linestyle='--', label='Mean Group 1')
plt.axhline(y=np.mean(group2), color='orange', linestyle='--', label='Mean Group 2')
plt.legend()
plt.show()
# Out:
# T-statistic: -4.51
# P-value: 0.0000
# Reject the null hypothesis: There is a significant difference between the means.

# %%
# 24 Perform a hypothesis test for population variance using a Chi-square distribution and interpret the results


import numpy as np
import scipy.stats as stats

# Step 1: Formulate Hypotheses
# Null Hypothesis (H0): The population variance is equal to a specified value (σ² = σ0²)
# Alternative Hypothesis (H1): The population variance is not equal to the specified value (σ² ≠ σ0²)

# Step 2: Simulate data
np.random.seed(42)  # For reproducibility
sample_size = 30
population_variance = 25  # Assume the true population variance is 25
sample_data = np.random.normal(loc=0, scale=np.sqrt(population_variance), size=sample_size)

# Step 3: Calculate the Chi-square Statistic
sample_variance = np.var(sample_data, ddof=1)  # Sample variance (Bessel's correction)
chi_square_statistic = (sample_size - 1) * sample_variance / population_variance

# Step 4: Determine the Critical Value
alpha = 0.05  # Significance level
df = sample_size - 1  # Degrees of freedom
critical_value_lower = stats.chi2.ppf(alpha / 2, df)  # Lower critical value
critical_value_upper = stats.chi2.ppf(1 - alpha / 2, df)  # Upper critical value

# Step 5: Interpret the Results
print(f"Chi-square Statistic: {chi_square_statistic:.2f}")
print(f"Critical Value Lower: {critical_value_lower:.2f}")
print(f"Critical Value Upper: {critical_value_upper:.2f}")

if chi_square_statistic < critical_value_lower or chi_square_statistic > critical_value_upper:
    print("Reject the null hypothesis: The population variance is significantly different from the specified value.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference from the specified population variance.")
# Out:
# Chi-square Statistic: 23.49
# Critical Value Lower: 16.05
# Critical Value Upper: 45.72
# Fail to reject the null hypothesis: There is no significant difference from the specified population variance.

# %%
# 25 Write a Python script to perform a Z-test for comparing proportions between two datasets or groups?

import numpy as np
import scipy.stats as stats

# Step 1: Define the data
# Group 1: successes and total trials
successes1 = 50  # Number of successes in group 1
trials1 = 200    # Total trials in group 1

# Group 2: successes and total trials
successes2 = 30  # Number of successes in group 2
trials2 = 150    # Total trials in group 2

# Step 2: Formulate Hypotheses
# Null Hypothesis (H0): p1 = p2 (the proportions are equal)
# Alternative Hypothesis (H1): p1 ≠ p2 (the proportions are not equal)

# Step 3: Calculate the Z-statistic
# Calculate the proportions
p1 = successes1 / trials1
p2 = successes2 / trials2

# Calculate the pooled proportion
p_pool = (successes1 + successes2) / (trials1 + trials2)

# Calculate the standard error
standard_error = np.sqrt(p_pool * (1 - p_pool) * (1/trials1 + 1/trials2))

# Calculate the Z-statistic
z_statistic = (p1 - p2) / standard_error

# Step 4: Determine the p-value
# For a two-tailed test
p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))

# Step 5: Interpret the Results
alpha = 0.05  # Significance level
print(f"Z-statistic: {z_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the proportions.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the proportions.")
# Out:
# Z-statistic: 1.10
# P-value: 0.2703
# Fail to reject the null hypothesis: There is no significant difference between the proportions.

# %%
# 26 Implement an F-test for comparing the variances of two datasets, then interpret and visualize the results


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Step 1: Simulate two independent samples
np.random.seed(42)  # For reproducibility
sample_size = 30
# Sample 1: Normal distribution with mean=50, std=10
sample1 = np.random.normal(loc=50, scale=10, size=sample_size)
# Sample 2: Normal distribution with mean=55, std=15
sample2 = np.random.normal(loc=55, scale=15, size=sample_size)

# Step 2: Perform the F-test
# Calculate the variances
var1 = np.var(sample1, ddof=1)  # Sample variance for sample1
var2 = np.var(sample2, ddof=1)  # Sample variance for sample2

# Calculate the F-statistic
f_statistic = var1 / var2  # F-statistic
df1 = sample_size - 1  # Degrees of freedom for sample1
df2 = sample_size - 1  # Degrees of freedom for sample2

# Calculate the p-value
p_value = 1 - stats.f.cdf(f_statistic, df1, df2)

# Step 3: Interpret the results
alpha = 0.05  # Significance level
print(f"Sample 1 Variance: {var1:.2f}")
print(f"Sample 2 Variance: {var2:.2f}")
print(f"F-statistic: {f_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: The variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: The variances are not significantly different.")

# Step 4: Visualize the results
plt.figure(figsize=(10, 6))
plt.boxplot([sample1, sample2], labels=['Sample 1', 'Sample 2'])
plt.title('Box Plot of Two Samples')
plt.ylabel('Values')
plt.grid()
plt.axhline(y=np.mean(sample1), color='blue', linestyle='--', label='Mean Sample 1')
plt.axhline(y=np.mean(sample2), color='orange', linestyle='--', label='Mean Sample 2')
plt.legend()
plt.show()
# Out:
# Sample 1 Variance: 81.00
# Sample 2 Variance: 195.06
# F-statistic: 0.42
# P-value: 0.9896
# Fail to reject the null hypothesis: The variances are not significantly different.
# <ipython-input-27-2e1150297074>:44: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([sample1, sample2], labels=['Sample 1', 'Sample 2'])

# %%
# 27 Perform a Chi-square test for goodness of fit with simulated data and analyze the results?



import numpy as np
import pandas as pd
from scipy.stats import chisquare
import matplotlib.pyplot as plt

# Step 1: Simulate observed data
# Simulate observed frequencies for a categorical variable (e.g., colors of balls)
np.random.seed(42)  # For reproducibility
observed_data = np.random.choice(['Red', 'Blue', 'Green'], size=100, p=[0.5, 0.3, 0.2])
observed_counts = pd.Series(observed_data).value_counts()

# Step 2: Define expected frequencies
# Assume we expect the proportions to be 50% Red, 30% Blue, and 20% Green
total_count = observed_counts.sum()
expected_counts = np.array([0.5 * total_count, 0.3 * total_count, 0.2 * total_count])

# Step 3: Perform the Chi-square test
chi2_statistic, p_value = chisquare(observed_counts, f_exp=expected_counts)

# Step 4: Analyze the results
alpha = 0.05  # Significance level
print(f"Observed Counts:\n{observed_counts}")
print(f"Expected Counts:\n{expected_counts}")
print(f"Chi-square Statistic: {chi2_statistic:.2f}")
print(f"P-value: {p_value:.4f}")

if p_value < alpha:
    print("Reject the null hypothesis: The observed data does not fit the expected distribution.")
else:
    print("Fail to reject the null hypothesis: The observed data fits the expected distribution.")

# Visualization
plt.figure(figsize=(10, 6))
plt.bar(observed_counts.index, observed_counts.values, alpha=0.6, label='Observed', color='blue', width=0.4)
plt.bar(observed_counts.index, expected_counts, alpha=0.6, label='Expected', color='orange', width=0.4)
plt.title('Observed vs Expected Counts')
plt.ylabel('Counts')
plt.xlabel('Categories')
plt.legend()
plt.show()
# Out:
# Observed Counts:
# Red      53
# Blue     29
# Green    18
# Name: count, dtype: int64
# Expected Counts:
# [50. 30. 20.]
# Chi-square Statistic: 0.41
# P-value: 0.8133
# Fail to reject the null hypothesis: The observed data fits the expected distribution.
